# %%
import random

class Ponto(object):
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y
    
    def __str__(self):
        return '<%s, %s>' % (self.x, self.y)
    
class Robo(Ponto):
    
    def subir(self):
        if self.x <= 0:
            print('Movimento proibido')
        else:
            self.x = self.x - 1
            
    def descer(self):
        if self.x >= 9:
            print('Movimento proibido')
        else:
            self.x = self.x + 1
    
    def esquerda(self):
        if self.y <= 0:
            print('Movimento proibido')
        else:
            self.y = self.y - 1
    
    def direita(self):
        if self.y <= 0:
            print('Movimento proibido')
        else:
            self.y = self.y + 1
            
class Recompensa(Ponto):
    
    def __init__(self, nome, x=0, y=0):
        super(Recompensa, self).__init__(x, y)
        self.nome = nome
    
    def __str__(self):
        return '%s <%s, %s>' % (self.nome, self.x, self.y)

# %%
recompensas = []
nomes = ['moeda', 'gasolina', 'arma']
for i in range(10):
    r = Recompensa(random.choice(nomes), random.randint(0, 9),  random.randint(0, 9))
    recompensas.append(r)

# %%
for r in recompensas:
    print(r)
# Out:
# moeda <7, 8>
# arma <5, 5>
# arma <6, 1>
# arma <4, 7>
# arma <4, 7>
# arma <2, 3>
# gasolina <1, 9>
# gasolina <1, 6>
# arma <3, 3>
# moeda <8, 8>

# %%
robo1 = Robo(random.randint(0, 9), random.randint(0, 9))
print(robo1)
# Out:
# <4, 3>

# %%
def checar_recompensa(robo, recompensas):
    """
    Imprime o nome da recompensa caso tenha encontrado
    """
    
    for r in recompensas:
        print(robo)
        if r.x == robo.x and r.y == robo.y:
            print('Encontrei %s',  r.nome)
        else:
            print('Não coletou recompensa, parei em:', robo)

while True:
    movimento = input("Estou em {}, Onde deseja ir? digite 'sair' para terminar".format(robo1))
    
    if movimento == 'subir':
        robo1.subir()
    elif movimento == 'descer':
        robo1.descer()
    elif movimento == 'esquerda':
        robo1.esquerda()
    elif movimento == 'direita':
        robo1.direita()
    elif movimento == 'sair':
        break
    else:
        print('Digite um movimento válido')
    checar_recompensa(robo1, recompensas)
print(robo1)
print('Fim do programa')
# Out:
# Estou em <4, 3>, Onde deseja ir? digite 'sair' para terminarsubir
# <3, 3>
# Não coletou recompensa, parei em: <3, 3>
# <3, 3>
# Não coletou recompensa, parei em: <3, 3>
# <3, 3>
# Não coletou recompensa, parei em: <3, 3>
# <3, 3>
# Não coletou recompensa, parei em: <3, 3>
# <3, 3>
# Não coletou recompensa, parei em: <3, 3>
# <3, 3>
# Não coletou recompensa, parei em: <3, 3>
# <3, 3>
# Não coletou recompensa, parei em: <3, 3>
# <3, 3>
# Não coletou recompensa, parei em: <3, 3>
# <3, 3>
# Encontrei %s arma
# <3, 3>
# Não coletou recompensa, parei em: <3, 3>
# Estou em <3, 3>, Onde deseja ir? digite 'sair' para terminardescer
# <4, 3>
# Não coletou recompensa, parei em: <4, 3>
# <4, 3>
# Não coletou recompensa, parei em: <4, 3>
# <4, 3>
# Não coletou recompensa, parei em: <4, 3>
# <4, 3>
# Não coletou recompensa, parei em: <4, 3>
# <4, 3>
# Não coletou recompensa, parei em: <4, 3>
# <4, 3>
# Não coletou recompensa, parei em: <4, 3>
# <4, 3>
# Não coletou recompensa, parei em: <4, 3>
# <4, 3>
# Não coletou recompensa, parei em: <4, 3>
# <4, 3>
# Não coletou recompensa, parei em: <4, 3>
# <4, 3>
# Não coletou recompensa, parei em: <4, 3>
# Estou em <4, 3>, Onde deseja ir? digite 'sair' para terminardireita
# <4, 4>
# Não coletou recompensa, parei em: <4, 4>
# <4, 4>
# Não coletou recompensa, parei em: <4, 4>
# <4, 4>
# Não coletou recompensa, parei em: <4, 4>
# <4, 4>
# Não coletou recompensa, parei em: <4, 4>
# <4, 4>
# Não coletou recompensa, parei em: <4, 4>
# <4, 4>
# Não coletou recompensa, parei em: <4, 4>
# <4, 4>
# Não coletou recompensa, parei em: <4, 4>
# <4, 4>
# Não coletou recompensa, parei em: <4, 4>
# <4, 4>
# Não coletou recompensa, parei em: <4, 4>
# <4, 4>
# Não coletou recompensa, parei em: <4, 4>
# Estou em <4, 4>, Onde deseja ir? digite 'sair' para terminardireita
# <4, 5>
# Não coletou recompensa, parei em: <4, 5>
# <4, 5>
# Não coletou recompensa, parei em: <4, 5>
# <4, 5>
# Não coletou recompensa, parei em: <4, 5>
# <4, 5>
# Não coletou recompensa, parei em: <4, 5>
# <4, 5>
# Não coletou recompensa, parei em: <4, 5>
# <4, 5>
# Não coletou recompensa, parei em: <4, 5>
# <4, 5>
# Não coletou recompensa, parei em: <4, 5>
# <4, 5>
# Não coletou recompensa, parei em: <4, 5>
# <4, 5>
# Não coletou recompensa, parei em: <4, 5>
# <4, 5>
# Não coletou recompensa, parei em: <4, 5>
# Estou em <4, 5>, Onde deseja ir? digite 'sair' para terminardireita
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# Estou em <4, 6>, Onde deseja ir? digite 'sair' para terminardireita
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Encontrei %s arma
# <4, 7>
# Encontrei %s arma
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# Estou em <4, 7>, Onde deseja ir? digite 'sair' para terminaresquerda
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# <4, 6>
# Não coletou recompensa, parei em: <4, 6>
# Estou em <4, 6>, Onde deseja ir? digite 'sair' para terminardireita
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Encontrei %s arma
# <4, 7>
# Encontrei %s arma
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
# <4, 7>
# Não coletou recompensa, parei em: <4, 7>
