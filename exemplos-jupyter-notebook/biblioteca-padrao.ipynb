# %%
import subprocess
import os
comando = "ping vanilton.net"
saida = subprocess
# Out:
# CompletedProcess(args=['ls', '-l'], returncode=0)

# %%
 os.uname()
# Out:
# posix.uname_result(sysname='Darwin', nodename='MacBook-Pro-de-Vanilton-2.local', release='17.4.0', version='Darwin Kernel Version 17.4.0: Sun Dec 17 09:19:54 PST 2017; root:xnu-4570.41.2~1/RELEASE_X86_64', machine='x86_64')

# %%
import requests

# %%
resposta = requests.get("http://vanilton.net")

# %%
resposta.text
# Out:
# '  <!doctype html>\r\n  <!--\r\n    Material Design Lite\r\n    Copyright 2015 Google Inc. All rights reserved.\r\n\r\n    Licensed under the Apache License, Version 2.0 (the "License");\r\n    you may not use this file except in compliance with the License.\r\n    You may obtain a copy of the License at\r\n\r\n        https://www.apache.org/licenses/LICENSE-2.0\r\n\r\n    Unless required by applicable law or agreed to in writing, software\r\n    distributed under the License is distributed on an "AS IS" BASIS,\r\n    WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.\r\n    See the License for the specific language governing permissions and\r\n    limitations under the License\r\n  -->\r\n  <html lang="pt-br">\r\n  <head>\r\n    <meta charset="utf-8">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta name="description" content="Qualidade de Software, Teste de Software, Automa̤̣o de Teste">\r\n    <meta name="viewport" content="width=de
# ...
